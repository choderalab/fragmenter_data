# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from openeye import oechem, oedepict
from fragmenter import utils
import json
import numpy as np
from openmoltools import openeye
import itertools
import glob
from matplotlib.backends.backend_pdf import PdfPages
import matplotlib.image as mpimg
import os

# %%
# load all directories
directories = [x[0] for x in os.walk(os.getcwd())]

# %%
all_data = {}
for kinase_inhibitor in directories[2:]:
    ki_key = kinase_inhibitor.split('/')[-1]
    all_data[ki_key] = []
    output_files = glob.glob('{}/*.output.json'.format(ki_key))
    for file in output_files:
        f = open(file, 'r')
        data = json.load(f)
        f.close
        # Check for errors
        error = data['error']
        if error:
            print(error)
            continue
        data['bond_orders'] = utils.bond_order_from_psi4_raw_output(data['raw_output'])
        data.pop('raw_output')
        all_data[ki_key].append(data)
# Out:
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Ibrutinib/Ibrutinib_12.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_0.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_1.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_10.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_100.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_101.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_102.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_103.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_104.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_105.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_106.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_107.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_108.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_109.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_11.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_110.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_111.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_112.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_113.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_114.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_115.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_116.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_117.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_118.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_119.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_12.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_120.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_121.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_122.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_123.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_124.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_125.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_126.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_127.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_128.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_129.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_13.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_130.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_131.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_132.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_133.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_134.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_135.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_14.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_15.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_16.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_17.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_18.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_19.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_2.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_20.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_21.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_22.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_23.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_24.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_25.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_26.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_27.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_28.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_29.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_3.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_30.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_31.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_32.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_33.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_34.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_35.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_36.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_37.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_38.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_39.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_4.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_40.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_41.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_42.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_43.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_44.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_45.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_46.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_47.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_48.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_49.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_5.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_50.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_51.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_52.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_53.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_54.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_55.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_56.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_57.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_58.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_59.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_6.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_60.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_61.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_62.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_63.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_64.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_65.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_66.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_67.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_68.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_69.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_7.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_70.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_71.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_72.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_73.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_74.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_75.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_76.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_77.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_78.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_79.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_8.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_80.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_81.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_82.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_83.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_84.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_85.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_86.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_87.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_88.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_89.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_9.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_90.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_91.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_92.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_93.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_94.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_95.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_96.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_97.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_98.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Abemaciclib/Abemaciclib_99.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Acalabrutinib/Acalabrutinib_0.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Acalabrutinib/Acalabrutinib_1.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Acalabrutinib/Acalabrutinib_10.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Acalabrutinib/Acalabrutinib_11.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Acalabrutinib/Acalabrutinib_12.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Acalabrutinib/Acalabrutinib_13.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Acalabrutinib/Acalabrutinib_14.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Acalabrutinib/Acalabrutinib_15.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Acalabrutinib/Acalabrutinib_16.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Acalabrutinib/Acalabrutinib_17.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Acalabrutinib/Acalabrutinib_18.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Acalabrutinib/Acalabrutinib_19.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Acalabrutinib/Acalabrutinib_2.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Acalabrutinib/Acalabrutinib_20.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Acalabrutinib/Acalabrutinib_21.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Acalabrutinib/Acalabrutinib_3.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Acalabrutinib/Acalabrutinib_4.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Acalabrutinib/Acalabrutinib_5.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Acalabrutinib/Acalabrutinib_6.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Acalabrutinib/Acalabrutinib_7.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Acalabrutinib/Acalabrutinib_8.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Acalabrutinib/Acalabrutinib_9.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Afatinib/Afatinib_0.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Afatinib/Afatinib_1.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Afatinib/Afatinib_10.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Afatinib/Afatinib_11.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Afatinib/Afatinib_12.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Afatinib/Afatinib_13.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Afatinib/Afatinib_14.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Afatinib/Afatinib_15.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Afatinib/Afatinib_16.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Afatinib/Afatinib_17.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Afatinib/Afatinib_18.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Afatinib/Afatinib_19.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Afatinib/Afatinib_2.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Afatinib/Afatinib_20.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Afatinib/Afatinib_21.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Afatinib/Afatinib_22.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Afatinib/Afatinib_23.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Afatinib/Afatinib_24.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Afatinib/Afatinib_25.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Afatinib/Afatinib_26.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Afatinib/Afatinib_27.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Afatinib/Afatinib_28.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Afatinib/Afatinib_29.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Afatinib/Afatinib_3.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Afatinib/Afatinib_30.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Afatinib/Afatinib_31.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Afatinib/Afatinib_32.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Afatinib/Afatinib_33.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Afatinib/Afatinib_34.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Afatinib/Afatinib_35.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Afatinib/Afatinib_36.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Afatinib/Afatinib_37.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Afatinib/Afatinib_38.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Afatinib/Afatinib_39.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Afatinib/Afatinib_4.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Afatinib/Afatinib_40.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Afatinib/Afatinib_41.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Afatinib/Afatinib_42.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Afatinib/Afatinib_43.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Afatinib/Afatinib_44.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Afatinib/Afatinib_45.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Afatinib/Afatinib_46.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Afatinib/Afatinib_47.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Afatinib/Afatinib_48.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Afatinib/Afatinib_49.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Afatinib/Afatinib_5.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Afatinib/Afatinib_50.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Afatinib/Afatinib_51.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Afatinib/Afatinib_52.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Afatinib/Afatinib_53.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Afatinib/Afatinib_54.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Afatinib/Afatinib_55.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Afatinib/Afatinib_56.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Afatinib/Afatinib_57.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Afatinib/Afatinib_58.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Afatinib/Afatinib_59.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Afatinib/Afatinib_6.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Afatinib/Afatinib_60.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Afatinib/Afatinib_61.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Afatinib/Afatinib_62.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Afatinib/Afatinib_63.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Afatinib/Afatinib_64.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Afatinib/Afatinib_65.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Afatinib/Afatinib_66.output.json' mode='r' encoding='UTF-8'>
#   import sys
# ...
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Vemurafenib/Vemurafenib_31.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Vemurafenib/Vemurafenib_32.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Vemurafenib/Vemurafenib_33.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Vemurafenib/Vemurafenib_34.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Vemurafenib/Vemurafenib_35.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Vemurafenib/Vemurafenib_36.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Vemurafenib/Vemurafenib_37.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Vemurafenib/Vemurafenib_38.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Vemurafenib/Vemurafenib_39.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Vemurafenib/Vemurafenib_4.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Vemurafenib/Vemurafenib_40.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Vemurafenib/Vemurafenib_41.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Vemurafenib/Vemurafenib_42.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Vemurafenib/Vemurafenib_43.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Vemurafenib/Vemurafenib_44.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Vemurafenib/Vemurafenib_45.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Vemurafenib/Vemurafenib_46.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Vemurafenib/Vemurafenib_47.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Vemurafenib/Vemurafenib_48.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Vemurafenib/Vemurafenib_49.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Vemurafenib/Vemurafenib_5.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Vemurafenib/Vemurafenib_50.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Vemurafenib/Vemurafenib_51.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Vemurafenib/Vemurafenib_52.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Vemurafenib/Vemurafenib_53.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Vemurafenib/Vemurafenib_54.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Vemurafenib/Vemurafenib_55.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Vemurafenib/Vemurafenib_56.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Vemurafenib/Vemurafenib_57.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Vemurafenib/Vemurafenib_58.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Vemurafenib/Vemurafenib_59.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Vemurafenib/Vemurafenib_6.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Vemurafenib/Vemurafenib_60.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Vemurafenib/Vemurafenib_61.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Vemurafenib/Vemurafenib_62.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Vemurafenib/Vemurafenib_63.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Vemurafenib/Vemurafenib_64.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Vemurafenib/Vemurafenib_65.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Vemurafenib/Vemurafenib_66.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Vemurafenib/Vemurafenib_67.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Vemurafenib/Vemurafenib_68.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Vemurafenib/Vemurafenib_69.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Vemurafenib/Vemurafenib_7.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Vemurafenib/Vemurafenib_70.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Vemurafenib/Vemurafenib_71.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Vemurafenib/Vemurafenib_72.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Vemurafenib/Vemurafenib_73.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Vemurafenib/Vemurafenib_74.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Vemurafenib/Vemurafenib_75.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Vemurafenib/Vemurafenib_76.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Vemurafenib/Vemurafenib_77.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Vemurafenib/Vemurafenib_78.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Vemurafenib/Vemurafenib_79.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Vemurafenib/Vemurafenib_8.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Vemurafenib/Vemurafenib_80.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Vemurafenib/Vemurafenib_81.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Vemurafenib/Vemurafenib_82.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Vemurafenib/Vemurafenib_83.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Vemurafenib/Vemurafenib_84.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Vemurafenib/Vemurafenib_85.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Vemurafenib/Vemurafenib_86.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Vemurafenib/Vemurafenib_87.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Vemurafenib/Vemurafenib_88.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Vemurafenib/Vemurafenib_89.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Vemurafenib/Vemurafenib_9.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Vemurafenib/Vemurafenib_90.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Vemurafenib/Vemurafenib_91.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Vemurafenib/Vemurafenib_92.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Vemurafenib/Vemurafenib_93.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Vemurafenib/Vemurafenib_94.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Vemurafenib/Vemurafenib_95.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Vemurafenib/Vemurafenib_96.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Vemurafenib/Vemurafenib_97.output.json' mode='r' encoding='UTF-8'>
#   import sys
# /Users/chayastern/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: ResourceWarning: unclosed file <_io.TextIOWrapper name='Vemurafenib/Vemurafenib_98.output.json' mode='r' encoding='UTF-8'>
#   import sys

# %%
for ki in all_data: 
    print(ki)
    conformations = len(all_data[ki])
    molecule, atom_map = utils.get_atom_map(tagged_smiles=all_data[ki][0]['tagged_smiles'])
    molecule_charged = openeye.get_charges(molecule)
    n_atoms = molecule.NumAtoms()
    # create bond dictionary (Skip all hydrogen bonds)
    bond_order_wiberg = {}
    bond_order_mayer = {}
    for bond in molecule.GetBonds():
        atom_1 = bond.GetBgn()
        atom_2 = bond.GetEnd()
        if atom_1.IsHydrogen() or atom_2.IsHydrogen():
            continue
        map_1 = atom_1.GetMapIdx()
        map_2 = atom_2.GetMapIdx()
        bond_order_wiberg[(map_1, map_2)] = np.zeros(conformations)
        bond_order_mayer[(map_1, map_2)] = np.zeros(conformations)

    # Populate array
    for k, data in enumerate(all_data[ki]):
        wiberg = data['bond_orders']['Wiberg_psi4']
        mayer = data['bond_orders']['Mayer_psi4']
        for i, j in bond_order_wiberg:
            bond_order_wiberg[(i, j)][k] = wiberg[i-1][j-1]
            bond_order_mayer[(i, j)][k] = mayer[i-1][j-1]
        
    # Generate figure with labeled map
    utils.png_atoms_labeled(all_data[ki][0]['tagged_smiles'], '{}_mapped.png'.format(ki), width=400, height=400, 
                            label_scale=2.0, scale_bondwidth=True)
    #Charge molecule
    # plot bond orders
    with PdfPages('{}_bond_orders.pdf'.format(ki)) as pdf:
        n = len(bond_order_wiberg)
        plots = 8
        chunk = n/(plots-2)
        keys = list(bond_order_wiberg.keys())
        #for i in range(chunk):
        #    for j in range(6)
        extra = n % (plots-2)
        print(extra)
        for i in range(int(chunk)):
            for j in range(plots-2):
                try:
                    key = keys[(plots-2)*i+j]
                except IndexError:
                    continue
                figure = plt.subplot2grid((4,2), (0, 0), rowspan=2)
                img = mpimg.imread('{}_mapped.png'.format(ki))
                imgplot = plt.imshow(img, interpolation='none')
                plt.xticks([])
                plt.yticks([])
                bond = bond_order_wiberg[key]
                atom_1 = molecule_charged.GetAtom(oechem.OEHasMapIdx(key[0]))
                atom_2 = molecule_charged.GetAtom(oechem.OEHasMapIdx(key[1]))
                bond_oe = molecule_charged.GetBond(atom_1, atom_2)
                wiberg_oe = bond_oe.GetData('WibergBondOrder')
                if j == 0:
                    plt.subplot2grid((4, 2), (0, 1))
                    plt.hist(bond_order_wiberg[key], alpha=0.5, label='Wiberg_psi4')
                    plt.hist(bond_order_mayer[key], alpha=0.5, label='Mayer_psi4')
                    plt.vlines(wiberg_oe, ymin=0, ymax=20, label='Wiberg_OE')
                    plt.title(key)
                    lgd = plt.legend(prop={'size': 8}, loc='center left', bbox_to_anchor=(1, 0.5))
                if j == 2:
                    plt.subplot(plots/2, 2, 3)
                if j == 1:
                    plt.subplot(plots/2, 2, 4)
                else:
                    plt.subplot(plots/2, 2, j+3)
                plt.hist(bond_order_wiberg[key], alpha=0.5, label='Wiberg_psi4')
                plt.hist(bond_order_mayer[key], alpha=0.5, label='Mayer_psi4')
                plt.vlines(wiberg_oe, ymin=0, ymax=20, label='Wiberg_OE')
                #plt.xlim(0.9, 2.0)
                plt.title(key)
                plt.tight_layout()
            pdf.savefig(dpi=300, bbox_extra_artist=(lgd,), bbox_inches='tight')
            plt.close()
        if extra:
            figure = plt.subplot2grid((4,2), (0, 0), rowspan=2)
            imgplot = plt.imshow(img, interpolation='none')
            plt.xticks([])
            plt.yticks([])
            bond = bond_order_wiberg[key]
            atom_1 = molecule_charged.GetAtom(oechem.OEHasMapIdx(key[0]))
            atom_2 = molecule_charged.GetAtom(oechem.OEHasMapIdx(key[1]))
            bond_oe = molecule_charged.GetBond(atom_1, atom_2)
            wiberg_oe = bond_oe.GetData('WibergBondOrder')
            for m in range(extra):
                key = keys[((plots-2)*i+j) + m+1]
                plt.subplot(plots/2, 2, 4+m)
                plt.hist(bond_order_wiberg[key], alpha=0.5, label='Wiberg_psi4')
                plt.hist(bond_order_mayer[key], alpha=0.5, label='Mayer_psi4')
                plt.vlines(wiberg_oe, ymin=0, ymax=20, label='Wiberg_OE')
                if m == 0:
                    lgd = plt.legend(prop={'size': 8}, loc='center left', bbox_to_anchor=(1, 0.5))
                #plt.xlim(0.9, 2.0)
                plt.title(key)
                plt.tight_layout()
            pdf.savefig(dpi=300, bbox_extra_artist=(lgd,), bbox_inches='tight')
            plt.close()
# Out:
# Abemaciclib
# 5
# Acalabrutinib
# 3
# Afatinib
# 1
# Alectinib
# 5
# Axitinib
# 1
# Bosutinib
# 3
# Brigatinib
# 2
# Cabozantinib
# 5
# Ceritinib
# 5
# Cobimetinib
# 3
# Crizotinib
# 3
# Dabrafenib
# 2
# Dasatinib
# 0
# Erlotinib
# 1
# Gefitinib
# 4
# Ibrutinib
# 1
# Idelalisib
# 5
# Imatinib
# 5
# Lapatinib
# 2
# Lenvatinib
# 3
# Midostaurin
# 3
# Neratinib
# 1
# Nilotinib
# 1
# Nintedanib
# 2
# Osimertinib
# 4
# Palbociclib
# 1
# Pazopanib
# 4
# Ponatinib
# 1
# Regorafenib
# 5
# Ribociclib
# 0
# Ruxolitinib
# 2
# Sorafenib
# 4
# Sunitinib
# 1
# Tofacitinib
# 1
# Trametinib
# 5
# Vandetanib
# 3
# Vemurafenib
# 0

# %%
for ki in all_data: 
    print(ki)
    conformations = len(all_data[ki])
    molecule, atom_map = utils.get_atom_map(tagged_smiles=all_data[ki][0]['tagged_smiles'])
    molecule_charged = openeye.get_charges(molecule)
    n_atoms = molecule.NumAtoms()
    # create bond dictionary (Skip all hydrogen bonds)
    bond_order_wiberg = {}
    bond_order_mayer = {}
    for bond in molecule.GetBonds():
        atom_1 = bond.GetBgn()
        atom_2 = bond.GetEnd()
        if atom_1.IsHydrogen() or atom_2.IsHydrogen():
            continue
        if atom_1.IsInRing() and atom_2.IsInRing():
            continue
        map_1 = atom_1.GetMapIdx()
        map_2 = atom_2.GetMapIdx()
        bond_order_wiberg[(map_1, map_2)] = np.zeros(conformations)
        bond_order_mayer[(map_1, map_2)] = np.zeros(conformations)

    # Populate array
    for k, data in enumerate(all_data[ki]):
        wiberg = data['bond_orders']['Wiberg_psi4']
        mayer = data['bond_orders']['Mayer_psi4']
        for i, j in bond_order_wiberg:
            bond_order_wiberg[(i, j)][k] = wiberg[i-1][j-1]
            bond_order_mayer[(i, j)][k] = mayer[i-1][j-1]
        
    # Generate figure with labeled map
    utils.png_atoms_labeled(all_data[ki][0]['tagged_smiles'], '{}_mapped.png'.format(ki), width=400, height=400, 
                            label_scale=2.0, scale_bondwidth=True)
    #Charge molecule
    # plot bond orders
    with PdfPages('{}_bond_orders_no_rings.pdf'.format(ki)) as pdf:
        n = len(bond_order_wiberg)
        plots = 8
        chunk = n/(plots-2)
        keys = list(bond_order_wiberg.keys())
        print(keys)
        #for i in range(chunk):
        #    for j in range(6)
        extra = n % (plots-2)
        for i in range(int(chunk)):
            for j in range(plots-2):
                try:
                    key = keys[(plots-2)*i+j]
                except IndexError:
                    continue
                print(key)
                figure = plt.subplot2grid((4,2), (0, 0), rowspan=2)
                img = mpimg.imread('{}_mapped.png'.format(ki))
                imgplot = plt.imshow(img, interpolation='none')
                plt.xticks([])
                plt.yticks([])
                bond = bond_order_wiberg[key]
                atom_1 = molecule_charged.GetAtom(oechem.OEHasMapIdx(key[0]))
                atom_2 = molecule_charged.GetAtom(oechem.OEHasMapIdx(key[1]))
                bond_oe = molecule_charged.GetBond(atom_1, atom_2)
                wiberg_oe = bond_oe.GetData('WibergBondOrder')
                if j == 0:
                    plt.subplot2grid((4, 2), (0, 1))
                    plt.hist(bond_order_wiberg[key], alpha=0.5, label='Wiberg_psi4')
                    plt.hist(bond_order_mayer[key], alpha=0.5, label='Mayer_psi4')
                    plt.vlines(wiberg_oe, ymin=0, ymax=20, label='Wiberg_OE')
                    plt.title(key)
                    lgd = plt.legend(prop={'size': 8}, loc='center left', bbox_to_anchor=(1, 0.5))
                if j == 2:
                    plt.subplot(plots/2, 2, 3)
                if j == 1:
                    plt.subplot(plots/2, 2, 4)
                else:
                    plt.subplot(plots/2, 2, j+3)
                plt.hist(bond_order_wiberg[key], alpha=0.5, label='Wiberg_psi4')
                plt.hist(bond_order_mayer[key], alpha=0.5, label='Mayer_psi4')
                plt.vlines(wiberg_oe, ymin=0, ymax=20, label='Wiberg_OE')
                #plt.xlim(0.9, 2.0)
                plt.title(key)
                plt.tight_layout()
            pdf.savefig(dpi=300, bbox_extra_artist=(lgd,), bbox_inches='tight')
            plt.close()
        if extra:
            figure = plt.subplot2grid((4,2), (0, 0), rowspan=2)
            imgplot = plt.imshow(img, interpolation='none')
            plt.xticks([])
            plt.yticks([])
            
            for m in range(extra):
                if chunk < 1:
                    i=0; j=0
                    key = keys[m]
                else:
                    key = keys[((plots-2)*i+j) + m+1]
                print(key)
                bond = bond_order_wiberg[key]
                atom_1 = molecule_charged.GetAtom(oechem.OEHasMapIdx(key[0]))
                atom_2 = molecule_charged.GetAtom(oechem.OEHasMapIdx(key[1]))
                bond_oe = molecule_charged.GetBond(atom_1, atom_2)
                wiberg_oe = bond_oe.GetData('WibergBondOrder')
                plt.subplot(plots/2, 2, 4+m)
                plt.hist(bond_order_wiberg[key], alpha=0.5, label='Wiberg_psi4')
                plt.hist(bond_order_mayer[key], alpha=0.5, label='Mayer_psi4')
                plt.vlines(wiberg_oe, ymin=0, ymax=20, label='Wiberg_OE')
                if m == 0:
                    lgd = plt.legend(prop={'size': 8}, loc='center left', bbox_to_anchor=(1, 0.5))
                #plt.xlim(0.9, 2.0)
                plt.title(key)
                plt.tight_layout()
            pdf.savefig(dpi=300, bbox_extra_artist=(lgd,), bbox_inches='tight')
            plt.close()
# Out:
# Abemaciclib
# [(8, 7), (7, 6), (3, 2), (2, 1), (11, 12), (12, 13), (22, 23), (28, 29), (29, 30), (29, 31), (26, 27), (16, 17)]
# (8, 7)
# (7, 6)
# (3, 2)
# (2, 1)
# (11, 12)
# (12, 13)
# (22, 23)
# (28, 29)
# (29, 30)
# (29, 31)
# (26, 27)
# (16, 17)
# Acalabrutinib
# [(31, 30), (30, 28), (28, 29), (28, 25), (6, 4), (4, 5), (4, 3), (3, 2), (2, 1), (20, 21)]
# (31, 30)
# (30, 28)
# (28, 29)
# (28, 25)
# (6, 4)
# (4, 5)
# (4, 3)
# (3, 2)
# (2, 1)
# (20, 21)
# Afatinib
# [(21, 20), (20, 16), (11, 29), (29, 30), (10, 9), (9, 7), (7, 8), (7, 6), (6, 5), (5, 4), (4, 2), (2, 1), (2, 3), (23, 28), (24, 27)]
# (21, 20)
# (20, 16)
# (11, 29)
# (29, 30)
# (10, 9)
# (9, 7)
# (7, 8)
# (7, 6)
# (6, 5)
# (5, 4)
# (4, 2)
# (2, 1)
# (2, 3)
# (23, 28)
# (24, 27)
# Alectinib
# [(21, 23), (23, 24), (9, 10), (3, 2), (2, 1), (13, 14), (13, 15)]
# (21, 23)
# (23, 24)
# (9, 10)
# (3, 2)
# (2, 1)
# (13, 14)
# (13, 15)
# Axitinib
# [(5, 3), (3, 4), (3, 2), (2, 1), (10, 11), (11, 12), (20, 21), (21, 22), (22, 23)]
# (5, 3)
# (3, 4)
# (3, 2)
# (2, 1)
# (10, 11)
# (11, 12)
# (20, 21)
# (21, 22)
# (22, 23)
# Bosutinib
# [(2, 35), (35, 36), (3, 24), (24, 25), (25, 26), (26, 27), (27, 28), (31, 34), (7, 13), (13, 14), (15, 23), (17, 22), (18, 20), (20, 21), (8, 11), (11, 12)]
# (2, 35)
# (35, 36)
# (3, 24)
# (24, 25)
# (25, 26)
# (26, 27)
# (27, 28)
# (31, 34)
# (7, 13)
# (13, 14)
# (15, 23)
# (17, 22)
# (18, 20)
# (20, 21)
# (8, 11)
# (11, 12)
# Brigatinib
# [(28, 27), (27, 25), (21, 20), (20, 17), (16, 39), (39, 40), (2, 1), (24, 38), (33, 34), (34, 35), (34, 36), (34, 37)]
# (28, 27)
# (27, 25)
# (21, 20)
# (20, 17)
# (16, 39)
# (39, 40)
# (2, 1)
# (24, 38)
# (33, 34)
# (34, 35)
# (34, 36)
# (34, 37)
# Cabozantinib
# [(19, 22), (22, 23), (23, 24), (23, 25), (25, 28), (28, 29), (28, 30), (30, 31), (34, 37), (16, 15), (15, 6), (12, 13), (13, 14), (3, 2), (2, 1)]
# (19, 22)
# (22, 23)
# (23, 24)
# (23, 25)
# (25, 28)
# (28, 29)
# (28, 30)
# (30, 31)
# (34, 37)
# (16, 15)
# (15, 6)
# (12, 13)
# (13, 14)
# (3, 2)
# (2, 1)
# Ceritinib
# [(26, 25), (25, 23), (19, 18), (18, 4), (5, 14), (14, 15), (15, 16), (15, 17), (2, 1), (22, 38), (31, 32), (32, 33), (32, 34), (32, 35), (35, 36), (35, 37)]
# (26, 25)
# (25, 23)
# (19, 18)
# (18, 4)
# (5, 14)
# (14, 15)
# (15, 16)
# (15, 17)
# (2, 1)
# (22, 38)
# (31, 32)
# (32, 33)
# (32, 34)
# (32, 35)
# (35, 36)
# (35, 37)
# Cobimetinib
# [(14, 12), (12, 13), (12, 10), (8, 31), (15, 22), (22, 23), (24, 30), (26, 29), (16, 21), (17, 20)]
# (14, 12)
# (12, 13)
# (12, 10)
# (8, 31)
# (15, 22)
# (22, 23)
# (24, 30)
# (26, 29)
# (16, 21)
# (17, 20)
# Crizotinib
# [(8, 11), (9, 10), (4, 2), (2, 1), (2, 13), (13, 14), (15, 31), (5, 12)]
# (8, 11)
# (9, 10)
# (4, 2)
# (2, 1)
# (2, 13)
# (13, 14)
# (15, 31)
# (5, 12)
# Dabrafenib
# [(21, 24), (24, 25), (25, 26), (25, 27), (25, 28), (29, 35), (33, 34), (22, 23), (5, 2), (2, 1), (2, 3), (2, 4), (14, 16)]
# (21, 24)
# (24, 25)
# (25, 26)
# (25, 27)
# (25, 28)
# (29, 35)
# (33, 34)
# (22, 23)
# (5, 2)
# (2, 1)
# (2, 3)
# (2, 4)
# (14, 16)
# Dasatinib
# [(31, 32), (26, 25), (25, 23), (23, 24), (23, 2), (4, 6), (6, 7), (11, 13), (17, 20), (20, 21), (21, 22), (27, 33)]
# (31, 32)
# (26, 25)
# (25, 23)
# (23, 24)
# (23, 2)
# (4, 6)
# (6, 7)
# (11, 13)
# (17, 20)
# (20, 21)
# (21, 22)
# (27, 33)
# Erlotinib
# [(29, 28), (28, 26), (22, 21), (21, 20), (11, 12), (12, 13), (13, 14), (14, 15), (15, 16), (6, 5), (5, 4), (4, 3), (3, 2), (2, 1)]
# (29, 28)
# (28, 26)
# (22, 21)
# (21, 20)
# (11, 12)
# (12, 13)
# (13, 14)
# (14, 15)
# (15, 16)
# (6, 5)
# (5, 4)
# (4, 3)
# (3, 2)
# (2, 1)
# Gefitinib
# [(24, 23), (23, 19), (3, 2), (2, 1), (8, 9), (9, 10), (10, 11), (11, 12), (12, 13), (28, 30), (27, 31)]
# (24, 23)
# (23, 19)
# (3, 2)
# (2, 1)
# (8, 9)
# (9, 10)
# (10, 11)
# (11, 12)
# (12, 13)
# (28, 30)
# (27, 31)
# Ibrutinib
# [(24, 23), (23, 20), (30, 34), (5, 3), (3, 4), (3, 2), (2, 1)]
# (24, 23)
# (23, 20)
# (30, 34)
# (5, 3)
# (3, 4)
# (3, 2)
# (2, 1)
# Idelalisib
# [(14, 15), (9, 13), (5, 3), (3, 2), (2, 1), (3, 23), (23, 24)]
# (14, 15)
# (9, 13)
# (5, 3)
# (3, 2)
# (2, 1)
# (3, 23)
# (23, 24)
# Imatinib
# [(10, 11), (11, 12), (13, 35), (16, 18), (18, 19), (19, 34), (19, 20), (23, 26), (26, 27), (30, 33)]
# (10, 11)
# (11, 12)
# (13, 35)
# (16, 18)
# (18, 19)
# (19, 34)
# (19, 20)
# (23, 26)
# (26, 27)
# (30, 33)
# Lapatinib
# [(38, 40), (34, 33), (33, 32), (32, 28), (29, 31), (25, 24), (24, 20), (9, 8), (8, 7), (7, 6), (6, 5), (5, 2), (2, 3), (2, 4), (2, 1)]
# (38, 40)
# (34, 33)
# (33, 32)
# (32, 28)
# (29, 31)
# (25, 24)
# (24, 20)
# (9, 8)
# (8, 7)
# (7, 6)
# (6, 5)
# (5, 2)
# (2, 3)
# (2, 4)
# (2, 1)
# Lenvatinib
# [(20, 23), (23, 24), (24, 25), (24, 26), (26, 27), (19, 30), (17, 16), (16, 9), (3, 2), (2, 1), (12, 13), (13, 14), (13, 15)]
# (20, 23)
# (23, 24)
# (24, 25)
# (24, 26)
# (26, 27)
# (19, 30)
# (17, 16)
# (16, 9)
# (3, 2)
# (2, 1)
# (12, 13)
# (13, 14)
# (13, 15)
# Midostaurin
# [(41, 39), (39, 40), (39, 37), (37, 5), (35, 36), (11, 12), (3, 2), (2, 1), (37, 38)]
# (41, 39)
# (39, 40)
# (39, 37)
# (37, 5)
# (35, 36)
# (11, 12)
# (3, 2)
# (2, 1)
# (37, 38)
# Neratinib
# [(25, 24), (24, 23), (23, 22), (31, 32), (19, 18), (18, 17), (4, 3), (3, 2), (2, 1), (5, 6), (6, 7), (7, 8), (7, 9), (9, 10), (10, 11), (11, 12), (12, 13), (12, 14), (34, 39), (39, 40)]
# (25, 24)
# (24, 23)
# (23, 22)
# (31, 32)
# (19, 18)
# (18, 17)
# (4, 3)
# (3, 2)
# (2, 1)
# (5, 6)
# (6, 7)
# (7, 8)
# (7, 9)
# (9, 10)
# (10, 11)
# (11, 12)
# (12, 13)
# (12, 14)
# (34, 39)
# (39, 40)
# Nilotinib
# [(9, 8), (8, 7), (2, 1), (5, 21), (21, 22), (21, 23), (23, 24), (32, 35), (26, 36), (36, 37), (36, 38), (36, 39)]
# (9, 8)
# (8, 7)
# (2, 1)
# (5, 21)
# (21, 22)
# (21, 23)
# (23, 24)
# (32, 35)
# (26, 36)
# (36, 37)
# (36, 38)
# (36, 39)
# Nintedanib
# [(35, 20), (20, 21), (33, 34), (25, 28), (28, 29), (28, 30), (30, 31), (20, 19), (19, 16), (13, 11), (11, 9), (9, 10), (9, 8), (8, 5), (2, 1), (11, 12)]
# (35, 20)
# (20, 21)
# (33, 34)
# (25, 28)
# (28, 29)
# (28, 30)
# (30, 31)
# (20, 19)
# (19, 16)
# (13, 11)
# (11, 9)
# (9, 10)
# (9, 8)
# (8, 5)
# (2, 1)
# (11, 12)
# Osimertinib
# [(2, 1), (13, 17), (17, 18), (19, 36), (36, 37), (21, 29), (29, 30), (29, 31), (31, 32), (32, 33), (33, 34), (33, 35), (22, 24), (24, 25), (25, 26), (25, 27), (27, 28)]
# (2, 1)
# (13, 17)
# (17, 18)
# (19, 36)
# (36, 37)
# (21, 29)
# (29, 30)
# (29, 31)
# (31, 32)
# (32, 33)
# (33, 34)
# (33, 35)
# (22, 24)
# (24, 25)
# (25, 26)
# (25, 27)
# (27, 28)
# Palbociclib
# [(22, 21), (21, 6), (10, 11), (12, 13), (13, 14), (13, 15), (2, 1)]
# (22, 21)
# (21, 6)
# (10, 11)
# (12, 13)
# (13, 14)
# (13, 15)
# (2, 1)
# Pazopanib
# [(21, 27), (22, 26), (17, 15), (15, 13), (9, 8), (8, 5), (3, 28), (28, 29), (28, 30), (28, 31), (2, 1), (15, 16)]
# (21, 27)
# (22, 26)
# (17, 15)
# (15, 13)
# (9, 8)
# (8, 5)
# (3, 28)
# (28, 29)
# (28, 30)
# (28, 31)
# (2, 1)
# (15, 16)
# Ponatinib
# [(10, 9), (9, 8), (8, 7), (2, 1), (5, 19), (19, 20), (19, 21), (21, 22), (26, 28), (28, 29), (28, 30), (28, 31), (25, 32), (32, 33), (36, 39)]
# (10, 9)
# (9, 8)
# (8, 7)
# (2, 1)
# (5, 19)
# (19, 20)
# (19, 21)
# (21, 22)
# (26, 28)
# (28, 29)
# (28, 30)
# (28, 31)
# (25, 32)
# (32, 33)
# (36, 39)
# Regorafenib
# [(15, 18), (18, 19), (19, 20), (19, 21), (21, 22), (24, 29), (29, 30), (29, 31), (29, 32), (25, 28), (14, 33), (12, 11), (11, 9), (5, 3), (3, 4), (3, 2), (2, 1)]
# (15, 18)
# (18, 19)
# (19, 20)
# (19, 21)
# (21, 22)
# (24, 29)
# (29, 30)
# (29, 31)
# (29, 32)
# (25, 28)
# (14, 33)
# (12, 11)
# (11, 9)
# (5, 3)
# (3, 4)
# (3, 2)
# (2, 1)
# Ribociclib
# [(21, 20), (20, 11), (6, 4), (4, 5), (4, 2), (2, 1), (2, 3)]
# (21, 20)
# (20, 11)
# (6, 4)
# (4, 5)
# (4, 2)
# (2, 1)
# (2, 3)
# Ruxolitinib
# [(13, 15), (15, 20), (15, 17), (17, 18), (18, 19)]
# (13, 15)
# (15, 20)
# (15, 17)
# (17, 18)
# (18, 19)
# Sorafenib
# [(15, 18), (18, 19), (19, 20), (19, 21), (21, 22), (26, 28), (28, 29), (28, 30), (28, 31), (25, 32), (12, 11), (11, 7), (5, 3), (3, 4), (3, 2), (2, 1)]
# (15, 18)
# (18, 19)
# (19, 20)
# (19, 21)
# (21, 22)
# (26, 28)
# (28, 29)
# (28, 30)
# (28, 31)
# (25, 32)
# (12, 11)
# (11, 7)
# (5, 3)
# (3, 4)
# (3, 2)
# (2, 1)
# Sunitinib
# [(26, 27), (18, 17), (17, 13), (15, 16), (11, 9), (9, 10), (9, 8), (8, 7), (7, 6), (6, 3), (3, 2), (2, 1), (3, 4), (4, 5), (12, 29), (21, 28)]
# (26, 27)
# (18, 17)
# (17, 13)
# (15, 16)
# (11, 9)
# (9, 10)
# (9, 8)
# (8, 7)
# (7, 6)
# (6, 3)
# (3, 2)
# (2, 1)
# (3, 4)
# (4, 5)
# (12, 29)
# (21, 28)
# Tofacitinib
# [(12, 10), (10, 8), (6, 21), (21, 22), (21, 23), (23, 24), (24, 25), (2, 1), (10, 11)]
# (12, 10)
# (10, 8)
# (6, 21)
# (21, 22)
# (21, 23)
# (23, 24)
# (24, 25)
# (2, 1)
# (10, 11)
# Trametinib
# [(29, 31), (31, 32), (32, 33), (32, 34), (7, 8), (2, 1), (6, 9), (5, 10), (10, 11), (12, 18), (14, 17), (19, 20), (22, 23)]
# (29, 31)
# (31, 32)
# (32, 33)
# (32, 34)
# (7, 8)
# (2, 1)
# (6, 9)
# (5, 10)
# (10, 11)
# (12, 18)
# (14, 17)
# (19, 20)
# (22, 23)
# Vandetanib
# [(23, 22), (22, 18), (10, 9), (9, 8), (8, 5), (2, 1), (15, 16), (16, 17), (28, 29), (26, 30)]
# (23, 22)
# (22, 18)
# (10, 9)
# (9, 8)
# (8, 5)
# (2, 1)
# (15, 16)
# (16, 17)
# (28, 29)
# (26, 30)
# Vemurafenib
# [(17, 15), (15, 16), (15, 12), (13, 14), (8, 7), (7, 4), (4, 5), (4, 6), (4, 3), (3, 2), (2, 1), (11, 33), (29, 32)]
# (17, 15)
# (15, 16)
# (15, 12)
# (13, 14)
# (8, 7)
# (7, 4)
# (4, 5)
# (4, 6)
# (4, 3)
# (3, 2)
# (2, 1)
# (11, 33)
# (29, 32)

# %%
chunk < 1
# Out:
# True

# %%
bond_order_wiberg
# Out:
# {(13,
#   15): array([ 0.96531033,  0.96140347,  0.96561644,  0.96261002,  0.96083476,
#          0.96272743,  0.96055377,  0.96336035,  0.96245069,  0.95921242,
#          0.96200967,  0.96493465,  0.96622186,  0.96398507,  0.96187875,
#          0.96100693,  0.96710752,  0.96314139,  0.96447836,  0.96151737,
#          0.959776  ,  0.96096294,  0.96479023,  0.96671726,  0.96105315,
#          0.96056596,  0.96509725,  0.96240964,  0.96303973,  0.96612375,
#          0.96207908,  0.96380013,  0.96135628]),
#  (15,
#   17): array([ 1.00079019,  1.00259996,  1.00170681,  1.00167352,  1.00298777,
#          1.00316537,  1.00072971,  1.0039953 ,  1.00262794,  1.00223396,
#          1.0006484 ,  1.00365676,  1.00053585,  0.99921092,  1.00060348,
#          1.00294935,  0.99436342,  0.99918388,  1.00447875,  0.99985693,
#          1.00277665,  1.00164158,  1.00296714,  1.00073129,  1.00260969,
#          1.00428801,  0.99887763,  1.00272827,  1.00228508,  1.00048538,
#          1.002717  ,  1.00069567,  1.00322186]),
#  (15,
#   20): array([ 1.01248172,  1.01442866,  1.01196858,  1.01393728,  1.01291965,
#          1.01274108,  1.01491152,  1.00955858,  1.01284292,  1.01207353,
#          1.01480756,  1.00943912,  1.01227662,  1.01500719,  1.01480317,
#          1.01019938,  1.0120859 ,  1.01501776,  1.00944409,  1.01349618,
#          1.01024765,  1.01178221,  1.00126672,  1.01233658,  1.01014634,
#          1.01019662,  1.00945512,  1.01448781,  1.01442859,  1.01229378,
#          1.0144622 ,  1.0097856 ,  1.01272113]),
#  (17,
#   18): array([ 1.06920074,  1.0683393 ,  1.06582539,  1.06774526,  1.06645477,
#          1.06484751,  1.0690462 ,  1.06501847,  1.06681533,  1.06920887,
#          1.06919019,  1.06513896,  1.06955789,  1.06845547,  1.06922322,
#          1.06681503,  1.07062642,  1.06821365,  1.06509048,  1.06743599,
#          1.06603495,  1.0683758 ,  1.06383956,  1.06917194,  1.06601225,
#          1.06891099,  1.07182729,  1.06799741,  1.06846731,  1.06948772,
#          1.06800699,  1.07060016,  1.0649699 ]),
#  (18,
#   19): array([ 3.21931044,  3.22002003,  3.20556868,  3.19942233,  3.19863663,
#          3.20477614,  3.21470689,  3.21643515,  3.198151  ,  3.20584872,
#          3.2145746 ,  3.21639151,  3.21883603,  3.19945155,  3.21457521,
#          3.21613117,  3.21442952,  3.1996925 ,  3.20364961,  3.2004036 ,
#          3.21642151,  3.21433689,  3.20717172,  3.21924002,  3.21651384,
#          3.20798216,  3.20685666,  3.22022256,  3.21994351,  3.21873193,
#          3.22038978,  3.20502388,  3.20468853])}

# %%
keys
# Out:
# [(13, 15), (15, 20), (15, 17), (17, 18), (18, 19)]

# %%
(plots-2)*i+j
# Out:
# 127

# %%
plots
# Out:
# 8

# %%
i
# Out:
# 18

# %%
j
# Out:
# 19
